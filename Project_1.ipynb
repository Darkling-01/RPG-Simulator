# %% [markdown]
# <a href="https://colab.research.google.com/github/Darkling-01/RPG-Simulator/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This project is for Machine Learning CSE5160

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from google.colab import files

print("SETUP COMPLETE...")
# Out:
# SETUP COMPLETE...

# %%
test = files.upload()
# Out:
#      <input type="file" id="files-92ef9673-daa5-49de-8ed8-1ca47d364ad4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92ef9673-daa5-49de-8ed8-1ca47d364ad4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
train = files.upload()
# Out:
#      <input type="file" id="files-ad02485a-c4ad-4ab2-b77c-63187f9ad87e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad02485a-c4ad-4ab2-b77c-63187f9ad87e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#test = pd.read_csv("test.csv", sep = ',')   # 25457 rows
train = pd.read_csv("train.csv", sep = ',') # 74110 rows
train.index
# Out:
# RangeIndex(start=0, stop=74111, step=1)

# %%
train.columns
